# %%
import sys
sys.path.append("..")
from utils import fit_and_plot, montecarlo_estimator
import numpy as np
import pandas as pd

# %%
class ExpModel:
    def forward(self, x, a):
        return a*x
    def backward(self, x, a):
        return  a
expmodel = ExpModel()
T = np.array([35.8, 30.85, 26.6, 23.05, 19.95])
J = np.array([379.2096, 316.008, 266.8512, 231.7392, 203.6496])
delT = np.ones_like(T)*np.sqrt(2)*0.1
delJ = np.array([10.8675272, 10.59020633, 10.4053916, 10.29083347, 10.21004154])
fit_and_plot(
    expmodel,
    T, 
    J,
    delT,
    delJ,
    1,
    None,
    r"$\Delta T (K)$",
    r"J (J/s)",
    "Fourier's Law",
    r"$J=\alpha \Delta T$",
    True,
    );
# Out:
# [[10.28158654  0.17134582]]
